# %%
# %pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\abhya\anaconda3\lib\site-packages (9.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
myConnection=mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="202nricbed",
    database="accidents103",
    use_pure=True)

# %%
cursor=myConnection.cursor()
cursor.execute("select Day_of_Week,count(*) from accident group by Day_of_Week order by Day_of_Week")  
data=cursor.fetchall()
print(data)
# Out:
# [(1, 8715), (2, 11404), (3, 12307), (4, 12359), (5, 12447), (6, 12944), (7, 10392)]

# %%
import matplotlib.pyplot as plt

# %%
l1=[]
l2=[]
for row in data:
    l1.append(row[0])
    l2.append(row[1])

# %%
plt.bar(l1,l2,color="red")
plt.title("Accident by on  Day of Week")
plt.xlabel("Day Of The Week")
plt.ylabel("Number of Accidents")
# Out:
# Text(0, 0.5, 'Number of Accidents')
