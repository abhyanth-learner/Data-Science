# %%
from json import encoder
from turtle import pd
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from streamlit import dataframe 

data={'color':['red','Blue','Green']}

df=pd.DataFrame(data)

encoder=LabelEncoder()

encoder.fit(df.color)

df['new_color']=encoder.transform(df['color'])
df
# Out:
#    color  new_color
# 0    red          2
# 1   Blue          0
# 2  Green          1

# %%
from pandas import read_csv
from IPython.display import display

col = ['age' , 'workclass' , 'fnlwgt' , 'education' , 'education-num' , 'marital-status' , 'occupation' , 'relationship' , 'race' , 'sex' , 'capital-gain' , 'capital-loss' , 'hours-per-week' , 'native-country' , 'income' ]
df=pd.read_csv("E:/Data Science/DataSets/adult.data",names=col)
display(df.head())
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
import numpy as np
df.workclass=df.workclass.str.strip()
df.workclass=df.workclass.replace('?',np.nan)
df.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
encoder2=LabelEncoder()

encoder2.fit(df.workclass)

df['workclass1']=encoder2.transform(df.workclass)

display(df)
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 0       39         State-gov   77516    Bachelors             13
# 1       50  Self-emp-not-inc   83311    Bachelors             13
# 2       38           Private  215646      HS-grad              9
# 3       53           Private  234721         11th              7
# 4       28           Private  338409    Bachelors             13
# ...    ...               ...     ...          ...            ...
# 32556   27           Private  257302   Assoc-acdm             12
# 32557   40           Private  154374      HS-grad              9
# 32558   58           Private  151910      HS-grad              9
# 32559   22           Private  201490      HS-grad              9
# 32560   52      Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
encoder2.classes_
# Out:
# array(['Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#        'Self-emp-inc', 'Self-emp-not-inc', 'State-gov', 'Without-pay',
#        nan], dtype=object)

# %%
mapping=dict(zip(encoder2.classes_,range(len(encoder2.classes_))))
mapping
# Out:
# {'Federal-gov': 0,
#  'Local-gov': 1,
#  'Never-worked': 2,
#  'Private': 3,
#  'Self-emp-inc': 4,
#  'Self-emp-not-inc': 5,
#  'State-gov': 6,
#  'Without-pay': 7,
#  nan: 8}

# %%
range(len(encoder2.classes_))
# Out:
# range(0, 9)

# %%
from sklearn.preprocessing import OrdinalEncoder

data = [['Phd'] , ['UG'] , ['MS'] ]

encoder3=OrdinalEncoder(categories=[['MS','Phd','UG']])

encoder3_data=encoder3.fit_transform(data)

encoder3_data
df['education'] = df.education.str.strip()

# %%
edu_cat = ['Preschool', '1st-4th' ,'5th-6th', '7th-8th' , '9th', '10th', '11th' , '12th', 'Bachelors' , 'HS-grad' , 'Masters', 'Some-college',  
           'Assoc-acdm', 'Assoc-voc', 'Doctorate', 'Prof-school' ]
len(edu_cat)
# Out:
# 16

# %%
edu_encoder = OrdinalEncoder(categories = [edu_cat])

df['education'] = edu_encoder.fit_transform(df[['education']])



display(df.head())
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516        8.0             13
# 1   50  Self-emp-not-inc   83311        8.0             13
# 2   38           Private  215646        9.0              9
# 3   53           Private  234721        6.0              7
# 4   28           Private  338409        8.0             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income  \
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df=df.drop(['workclass1'],axis=1)

# %%
display(df.head())
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516        8.0             13
# 1   50  Self-emp-not-inc   83311        8.0             13
# 2   38           Private  215646        9.0              9
# 3   53           Private  234721        6.0              7
# 4   28           Private  338409        8.0             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
label_encoder = LabelEncoder()

columns_to_encode = ['workclass' , 'marital-status' , 'relationship' , 'race' , 'native-country' , 'occupation' ,  'income']

for col in columns_to_encode:
    df[col] = label_encoder.fit_transform(df[col])

display(df)
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          6   77516        8.0             13               4
# 1       50          5   83311        8.0             13               2
# 2       38          3  215646        9.0              9               0
# 3       53          3  234721        6.0              7               2
# 4       28          3  338409        8.0             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302       12.0             12               2
# 32557   40          3  154374        9.0              9               2
# 32558   58          3  151910        9.0              9               6
# 32559   22          3  201490        9.0              9               4
# 32560   52          4  287927        9.0              9               2
#
#        occupation  relationship  race      sex  capital-gain  capital-loss  \
# ...

# %%
import dis
from sklearn.preprocessing import OneHotEncoder

gender_encoder=OneHotEncoder(sparse_output=False)

df['sex']=gender_encoder.fit_transform(df[['sex']])

display(df)
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          6   77516        8.0             13               4
# 1       50          5   83311        8.0             13               2
# 2       38          3  215646        9.0              9               0
# 3       53          3  234721        6.0              7               2
# 4       28          3  338409        8.0             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302       12.0             12               2
# 32557   40          3  154374        9.0              9               2
# 32558   58          3  151910        9.0              9               6
# 32559   22          3  201490        9.0              9               4
# 32560   52          4  287927        9.0              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()

df['fnlwgt']=scaler.fit_transform(df[['fnlwgt']])

display(df)
# Out:
#        age  workclass    fnlwgt  education  education-num  marital-status  \
# 0       39          6  0.044302        8.0             13               4
# 1       50          5  0.048238        8.0             13               2
# 2       38          3  0.138113        9.0              9               0
# 3       53          3  0.151068        6.0              7               2
# 4       28          3  0.221488        8.0             13               2
# ...    ...        ...       ...        ...            ...             ...
# 32556   27          3  0.166404       12.0             12               2
# 32557   40          3  0.096500        9.0              9               2
# 32558   58          3  0.094827        9.0              9               6
# 32559   22          3  0.128499        9.0              9               4
# 32560   52          4  0.187203        9.0              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

for column in df.columns:
    plt.figure(figsize = (4,2))
    sns.histplot(df[column], kde = True, bins = 30, color = 'blue')
    plt.title(f"{column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler1=StandardScaler()

df['hours-per-week']=scaler1.fit_transform(df[['hours-per-week']])

display(df)
# Out:
#        age  workclass    fnlwgt  education  education-num  marital-status  \
# 0       39          6  0.044302        8.0             13               4
# 1       50          5  0.048238        8.0             13               2
# 2       38          3  0.138113        9.0              9               0
# 3       53          3  0.151068        6.0              7               2
# 4       28          3  0.221488        8.0             13               2
# ...    ...        ...       ...        ...            ...             ...
# 32556   27          3  0.166404       12.0             12               2
# 32557   40          3  0.096500        9.0              9               2
# 32558   58          3  0.094827        9.0              9               6
# 32559   22          3  0.128499        9.0              9               4
# 32560   52          4  0.187203        9.0              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...
