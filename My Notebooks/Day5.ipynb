# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame()

# %%
df=pd.read_csv("E:/Data Science/DataSets/adult.data")
print(df)
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
from IPython.display import display
display(df.head())
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
col = ['age' , 'workclass' , 'fnlwgt' , 'education' , 'education-num' , 'marital-status' , 'occupation' , 'relationship' , 'race' , 'sex' , 'capital-gain' , 'capital-loss' , 'hours-per-week' , 'native-country' , 'income' ]

# %%
df=pd.read_csv("E:/Data Science/DataSets/adult.data",names=col)
display(df.head())
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df['age'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='age'>

# %%
df['workclass'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='workclass'>

# %%
df.sample(10)
# Out:
#        age     workclass  fnlwgt      education  education-num  \
# 15360   48   Federal-gov  483261   Some-college             10
# 32114   40       Private  137225        Masters             14
# 8560    32       Private  112176   Some-college             10
# 20782   30             ?  108464   Some-college             10
# 26595   38       Private  165930        HS-grad              9
# 25664   47       Private  190072   Some-college             10
# 22437   32       Private  197457        HS-grad              9
# 1424    53   Federal-gov  130703        HS-grad              9
# 29082   29       Private  136985     Assoc-acdm             12
# 9593    24       Private  257500        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 15360        Never-married        Adm-clerical   Not-in-family   Black
# 32114   Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %%
df.count()
# Out:
# age               32561
# workclass         32561
# fnlwgt            32561
# education         32561
# education-num     32561
# marital-status    32561
# occupation        32561
# relationship      32561
# race              32561
# sex               32561
# capital-gain      32561
# capital-loss      32561
# hours-per-week    32561
# native-country    32561
# income            32561
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df[['age','occupation']]
# Out:
#        age          occupation
# 0       39        Adm-clerical
# 1       50     Exec-managerial
# 2       38   Handlers-cleaners
# 3       53   Handlers-cleaners
# 4       28      Prof-specialty
# ...    ...                 ...
# 32556   27        Tech-support
# 32557   40   Machine-op-inspct
# 32558   58        Adm-clerical
# 32559   22        Adm-clerical
# 32560   52     Exec-managerial
#
# [32561 rows x 2 columns]

# %%
from sympy import rotations


sns.barplot(x="marital-status",y='age',data=df)

plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x="marital-status",y='hours-per-week',hue='income',data=df)

plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(x='age',y='hours-per-week',data=df)
# Out:
# <Axes: xlabel='age', ylabel='hours-per-week'>

# %%
from sympy import true


sns.displot(df,x='age',col='workclass',kde=True,bins=5,color='blue')

# %%
sns.scatterplot(x='age',y='hours-per-week',data=df)
# Out:
# <Axes: xlabel='age', ylabel='hours-per-week'>

# %%
sns.jointplot(x='age',y='hours-per-week',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.stripplot(x='income',y='age',hue='sex',data=df)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
df.loc[2:6,'age':'occupation']
# Out:
#    age workclass  fnlwgt   education  education-num          marital-status  \
# 2   38   Private  215646     HS-grad              9                Divorced
# 3   53   Private  234721        11th              7      Married-civ-spouse
# 4   28   Private  338409   Bachelors             13      Married-civ-spouse
# 5   37   Private  284582     Masters             14      Married-civ-spouse
# 6   49   Private  160187         9th              5   Married-spouse-absent
#
#            occupation
# 2   Handlers-cleaners
# 3   Handlers-cleaners
# 4      Prof-specialty
# 5     Exec-managerial
# 6       Other-service

# %%
df.iloc[2:10,2:8]
# Out:
#    fnlwgt   education  education-num          marital-status  \
# 2  215646     HS-grad              9                Divorced
# 3  234721        11th              7      Married-civ-spouse
# 4  338409   Bachelors             13      Married-civ-spouse
# 5  284582     Masters             14      Married-civ-spouse
# 6  160187         9th              5   Married-spouse-absent
# 7  209642     HS-grad              9      Married-civ-spouse
# 8   45781     Masters             14           Never-married
# 9  159449   Bachelors             13      Married-civ-spouse
#
#            occupation    relationship
# 2   Handlers-cleaners   Not-in-family
# 3   Handlers-cleaners         Husband
# 4      Prof-specialty            Wife
# 5     Exec-managerial            Wife
# 6       Other-service   Not-in-family
# 7     Exec-managerial         Husband
# 8      Prof-specialty   Not-in-family
# 9     Exec-managerial         Husband

# %%
#if there is NaN data then we try to replace it with mode of the data if possible
df.info()
#object is string type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.select_dtypes(include='int64').columns
df.select_dtypes(include='object').columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype='object')

# %%
df.shape
# Out:
# (32561, 15)

# %%
df[df.age<18]
# Out:
#        age workclass  fnlwgt education  education-num  marital-status  \
# 106     17         ?  304873      10th              6   Never-married
# 209     17   Private   65368      11th              7   Never-married
# 262     17   Private  245918      11th              7   Never-married
# 271     17   Private  191260       9th              5   Never-married
# 335     17   Private  270942   5th-6th              3   Never-married
# ...    ...       ...     ...       ...            ...             ...
# 31772   17         ?  256173      10th              6   Never-married
# 31864   17   Private  214787      12th              8   Never-married
# 31959   17   Private   24090   HS-grad              9   Never-married
# 32282   17   Private  311907      11th              7   Never-married
# 32447   17   Private  117798      10th              6   Never-married
#
#              occupation     relationship    race      sex  capital-gain  \
# ...

# %%
df['age'][(df.age <20)| (df.age>70)]
# Out:
# 26       19
# 37       19
# 51       18
# 70       19
# 74       79
#          ..
# 32496    18
# 32501    71
# 32525    81
# 32539    71
# 32542    72
# Name: age, Length: 2197, dtype: int64

# %%
df.age.unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
df.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df['workclass']=df.workclass.str.strip()

# %%
df.workclass=df.workclass.replace('?',np.nan)

# %%
df['hours-per-week'].sum()
df['hours-per-week'].min()
df['hours-per-week'].max()
# Out:
# 99

# %%
df['hours-per-week'].mean()
df['hours-per-week'].median()
df['hours-per-week'].mode()
# Out:
# 0    40
# Name: hours-per-week, dtype: int64

# %%
df['hours-per-week'].std()   #how far are we from mean
# Out:
# 12.34742868173081

# %%
df[['age','hours-per-week']].cov()
# Out:
#                       age  hours-per-week
# age             186.06140       11.580130
# hours-per-week   11.58013      152.458995

# %%
df[['age','hours-per-week']].corr() #if this is positive then if a increases b is also increasing if its negative then its like inversly propotional
# Out:
#                      age  hours-per-week
# age             1.000000        0.068756
# hours-per-week  0.068756        1.000000

# %%
corr_matrix=df[['age','hours-per-week']].corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt=".2f")
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include='object')
# Out:
#        workclass education       marital-status       occupation relationship  \
# count      30725     32561                32561            32561        32561
# unique         8        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#           race    sex  native-country  income
# count    32561  32561           32561   32561
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     27816  21790           29170   24720

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation           0
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# income               0
# dtype: int64

# %%
df1=df.copy()

# %%
df1.dropna(axis=0,inplace=True)

# %%
df1.shape
# Out:
# (30725, 15)

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
sns.countplot(x=df.workclass)
plt.xticks(rotation=45)
plt.show()

# %%
from sympy import plot


df['workclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df2=df.copy()

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age'].skew()
# Out:
# 0.5587433694130484

# %%
df.age.kurt()
# Out:
# -0.16612745957143904

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df2=df2.workclass.fillna("Private")

# %%
df2.isna().sum()
# Out:
# 0
