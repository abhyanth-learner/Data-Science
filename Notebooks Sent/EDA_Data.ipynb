# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Pandas Series

# %%
ser  = pd.Series()

# %%
print(ser)
# Out:
# Series([], dtype: object)

# %%
data = np.array([1,2,3,4,5])

# %%
ser = pd.Series(data)

# %%
print(ser[1])
# Out:
# 2

# %%
list_data = [10,20,30,40,50]
ser = pd.Series(list_data)
print(ser)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# # Pandas DataFrame

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = {
    "Name" : ['Puneet' , 'Rahul' , 'amit'],
    "age" : [ 28, 29 ,30]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  age
# 0  Puneet   28
# 1   Rahul   29
# 2    amit   30

# %%
df = pd.read_csv("C:/Users/Prikshit_Ishi/Downloads/census+income/adult.data")

# %%
print(df)
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
from IPython.display import display

display(df.head())
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
col = ['age' , 'workclass' , 'fnlwgt' , 'education' , 'education-num' , 'marital-status' , 'occupation' , 'relationship' , 'race' , 'sex' , 'capital-gain' , 'capital-loss' , 'hours-per-week' , 'native-country' , 'income' ]

df = pd.read_csv("C:/Users/Prikshit_Ishi/Downloads/census+income/adult.data", names = col)

# %%
display(df.head(10))
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df['age'].head().plot(kind = "bar")
# Out:
# <Axes: >

# %%
df.sample(5)
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 1888    22   Self-emp-not-inc  143062      HS-grad              9
# 6335    46            Private  141483      HS-grad              9
# 21298   25            Private  232914    Bachelors             13
# 31880   59   Self-emp-not-inc   83542   Assoc-acdm             12
# 7634    62          State-gov  221558      Masters             14
#
#             marital-status       occupation    relationship    race      sex  \
# 1888         Never-married    Other-service       Own-child   White     Male
# 6335    Married-civ-spouse            Sales            Wife   White   Female
# 21298   Married-civ-spouse     Adm-clerical            Wife   Black   Female
# 31880             Divorced     Tech-support   Not-in-family   White     Male
# 7634             Separated   Prof-specialty       Unmarried   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %%
df.tail(12)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation     relationship  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df[['age' , 'income']]
# Out:
#        age  income
# 0       39   <=50K
# 1       50   <=50K
# 2       38   <=50K
# 3       53   <=50K
# 4       28   <=50K
# ...    ...     ...
# 32556   27   <=50K
# 32557   40    >50K
# 32558   58   <=50K
# 32559   22   <=50K
# 32560   52    >50K
#
# [32561 rows x 2 columns]

# %%
sns.barplot(x = "marital-status" , y = "age" , data = df)

plt.xticks(rotation = 45)

plt.show()

# %%
sns.barplot(y = "marital-status" , x = "hours-per-week", hue = 'income', data = df)

plt.xticks(rotation = 45)

plt.show()

# %%
# people who are having more then 50k salary , they are working more then 40 hour per week

# %%
sns.lineplot( x = 'age' , y = 'hours-per-week' , data = df)
# Out:
# <Axes: xlabel='age', ylabel='hours-per-week'>

# %%
sns.displot(df , x = 'age' , col = 'workclass')

# %%
sns.scatterplot(x = 'age' , y = 'hours-per-week' , data = df)
# Out:
# <Axes: xlabel='age', ylabel='hours-per-week'>

# %%
sns.jointplot(x = 'age' , y = 'hours-per-week' , data = df, kind = 'reg')

# %%
sns.pairplot(df)

# %%
sns.stripplot( x = 'income' , y = 'age' , hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %% [markdown]
# #### Indexing

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.loc[ 12:60 , 'age' : 'occupation']
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 12   23            Private  122272      Bachelors             13
# 13   32            Private  205019     Assoc-acdm             12
# 14   40            Private  121772      Assoc-voc             11
# 15   34            Private  245487        7th-8th              4
# 16   25   Self-emp-not-inc  176756        HS-grad              9
# 17   32            Private  186824        HS-grad              9
# 18   38            Private   28887           11th              7
# 19   43   Self-emp-not-inc  292175        Masters             14
# 20   40            Private  193524      Doctorate             16
# 21   54            Private  302146        HS-grad              9
# 22   35        Federal-gov   76845            9th              5
# 23   43            Private  117037           11th              7
# 24   59            Private  109015        HS-grad              9
# ...

# %%
df[2:10]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# ...

# %%
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Exploratory Data Analysis:
    # Understand the dataset: Graphs, info(0, shape, description()
    # Find the NaN 
    # find the duplicates
    # Statistical analysis: mean, median, mode, SD, Cov
    # find Outlier

# Data Cleaning: 1. Remove NaN
    # Remove the Duplicates
    # handle the outliers

# %% [markdown]
# #### EDA - understanding the dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
df.select_dtypes(include = 'object').columns
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype='object')

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# #### EDA : Filter

# %%
df[df.age < 20]
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 26      19   Private  168294        HS-grad              9
# 37      19   Private  544091        HS-grad              9
# 51      18   Private  226956        HS-grad              9
# 70      19   Private  101509   Some-college             10
# 78      18   Private  309634           11th              7
# ...    ...       ...     ...            ...            ...
# 32392   18   Private  200047           12th              8
# 32437   19   Private   60890        HS-grad              9
# 32443   18   Private   41381        HS-grad              9
# 32447   17   Private  117798           10th              6
# 32496   18   Private  436163           11th              7
#
#            marital-status       occupation    relationship    race      sex  \
# 26          Never-married     Craft-repair       Own-child   White     Male
# 37      Married-AF-spouse     Adm-clerical            Wife   White   Female
# ...

# %%
# Masking

df['age'][(df['age'] < 20) | (df['age'] > 70)]
# Out:
# 26       19
# 37       19
# 51       18
# 70       19
# 74       79
#          ..
# 32496    18
# 32501    71
# 32525    81
# 32539    71
# 32542    72
# Name: age, Length: 2197, dtype: int64

# %%
df.nlargest(5, 'age')
# Out:
#       age workclass  fnlwgt      education  education-num  \
# 222    90   Private   51744        HS-grad              9
# 1040   90   Private  137018        HS-grad              9
# 1935   90   Private  221832      Bachelors             13
# 2303   90   Private   52386   Some-college             10
# 2891   90   Private  171956   Some-college             10
#
#            marital-status        occupation    relationship  \
# 222         Never-married     Other-service   Not-in-family
# 1040        Never-married     Other-service   Not-in-family
# 1935   Married-civ-spouse   Exec-managerial         Husband
# 2303        Never-married     Other-service   Not-in-family
# 2891            Separated      Adm-clerical       Own-child
#
#                      race      sex  capital-gain  capital-loss  \
# 222                 Black     Male             0          2206
# 1040                White   Female             0             0
# ...

# %%
df.nsmallest(4, 'age')
# Out:
#      age workclass  fnlwgt education  education-num  marital-status  \
# 106   17         ?  304873      10th              6   Never-married
# 209   17   Private   65368      11th              7   Never-married
# 262   17   Private  245918      11th              7   Never-married
# 271   17   Private  191260       9th              5   Never-married
#
#          occupation relationship    race      sex  capital-gain  capital-loss  \
# 106               ?    Own-child   White   Female         34095             0
# 209           Sales    Own-child   White   Female             0             0
# 262   Other-service    Own-child   White     Male             0             0
# 271   Other-service    Own-child   White     Male          1055             0
#
#      hours-per-week  native-country  income
# 106              32   United-States   <=50K
# 209              12   United-States   <=50K
# 262              12   United-States   <=50K
# 271              24   United-States   <=50K

# %%
df[['age','income']].where(df['age'] > 30)
# Out:
#         age          workclass    fnlwgt   education  education-num  \
# 0      39.0          State-gov   77516.0   Bachelors           13.0
# 1      50.0   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2      38.0            Private  215646.0     HS-grad            9.0
# 3      53.0            Private  234721.0        11th            7.0
# 4       NaN                NaN       NaN         NaN            NaN
# ...     ...                ...       ...         ...            ...
# 32556   NaN                NaN       NaN         NaN            NaN
# 32557  40.0            Private  154374.0     HS-grad            9.0
# 32558  58.0            Private  151910.0     HS-grad            9.0
# 32559   NaN                NaN       NaN         NaN            NaN
# 32560  52.0       Self-emp-inc  287927.0     HS-grad            9.0
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df['workclass'] = df.workclass.str.strip()

# %%
df.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', nan, 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['workclass'] = df['workclass'].replace('?' , np.nan)

# %% [markdown]
# #### EDA: Statistical summary

# %%
df['hours-per-week'].sum()
# Out:
# 1316684

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
df['hours-per-week'].max()
# Out:
# 99

# %%
df['hours-per-week'].mean()
# Out:
# 40.437455852092995

# %%
df['hours-per-week'].median()
# Out:
# 40.0

# %%
df['age'].mode()
# Out:
# 0    36
# Name: age, dtype: int64

# %%
df['hours-per-week'].std()
# Out:
# 12.34742868173081

# %%
df[['age','hours-per-week']].cov()
# Out:
#                       age  hours-per-week
# age             186.06140       11.580130
# hours-per-week   11.58013      152.458995

# %%
df[['age','hours-per-week']].corr()
# Out:
#                      age  hours-per-week
# age             1.000000        0.068756
# hours-per-week  0.068756        1.000000

# %% [markdown]
# # heatmap
#
# corr_matrix = df[['age' , 'hours-per-week', 'capital-gain']].corr()
# sns.heatmap(corr_matrix , annot = True , cmap = "coolwarm" , fmt = ".2f")

# %%
df.describe(include = 'object')
# Out:
#        workclass education       marital-status       occupation relationship  \
# count      30725     32561                32561            32561        32561
# unique         8        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#           race    sex  native-country  income
# count    32561  32561           32561   32561
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     27816  21790           29170   24720

# %% [markdown]
# # DATA CLEANING: cleaning of NULL / NaN values

# %%
# Approach-1: Delete the records or Column

# Approach-2: filling the NaN
    # mean
    #median
    # mode

# appraoch-3: filling the constants

# Appraoch-4: bfill , ffill : 10, 20, 30, ---  50 , 60

# Approach-5: Interpolate: slice

# Appraoch-6: Supervised learning model

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation           0
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# income               0
# dtype: int64

# %%
# Approach-1: Delete the records or Column
df1 = df.copy()

# %%
df1.shape
# Out:
# (32561, 15)

# %%
df1.dropna(axis = 0, inplace = True)

# %%
df1.shape
# Out:
# (30725, 15)

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
sns.countplot(x = df.workclass)
plt.xticks(rotation = 45)
plt.show()

# %%
df['workclass'].value_counts().plot(kind = 'pie' , autopct = "%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
# Approach-2: filling the NaN
    # mean
    #median
    # mode

df2 = df.copy()

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df["age"].skew()
# Out:
# 0.5587433694130484

# %%
df["age"].kurt()
# Out:
# -0.16612745957143904

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df2 = df2.workclass.fillna("Private")

# %%
df2.isnull().sum()
# Out:
# 0
